# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/abcdef.bmp')
img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
cv2_imshow(gImg1)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gImg1], [0], None, [256], [0, 255])
plt.plot(hist)

# %%
#img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/rice.bmp')
#img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/cell.bmp')
img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/cell-bright.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg1 = cv2.cvtColor(RGB_img, cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
cv2_imshow(gImg1)
# Out:
# (360, 360)
# <PIL.Image.Image image mode=L size=360x360>

# %%
hist = cv2.calcHist([gImg1], [0], None, [256], [0, 255])
plt.plot(hist)

# %%
gBin = np.zeros((gImg1.shape[0], gImg1.shape[1]))

# %%
T = 180

for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    if gImg1[h, w] > T:
      gBin[h, w] = 255
    else:
      gBin[h, w] = 0

plt.imshow(gBin, cmap = 'gray')
##cv2_imshow(gBin)

# %%
T1 = 50
T2 = 0
T0 = 1
outImg = np.zeros((gImg1.shape[0], gImg1.shape[1]))

# %%
def threshold_update(h, w, img, output, T1):
  sum1 = 0
  count1 = 0
  sum2 = 0
  count2 = 0

  for h in range(img.shape[0]):
    for w in range(img.shape[1]):
      if(output[h,w] == 255):
        sum1 = sum1 + img[h,w]
        count1 = count1 + 1
      else:
        sum2 = sum2 + img[h,w]
        count2 = count2 + 1

  avg1 = sum1 / count1
  avg2 = sum2 / count2

  T2 = np.int32(avg1 + avg2)/2
  return T2

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    if (gImg1[h, w] > T1):
      outImg[h, w] = 255
    else:
      outImg[h, w] = 0

# %%
while True:
  T2 = threshold_update(gImg1.shape[0], gImg1.shape[1], gImg1, outImg, T1)

  if(np.abs(T2-T1) < T0):
      for w in range(gImg1.shape[1]):
        if (gImg1[h, w] > T1):
         outImg[h, w] = 255
        else:
         outImg[h, w] = 0
        break;
  else:
    T1 = T2
    for h in range(gImg1.shape[0]):
      for w in range(gImg1.shape[1]):
        if(gImg1[h, w] > T2):
          outImg[h, w] = 255
        else:
          outImg[h, w] = 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-47-0ec05f43780c> in <cell line: 1>()
#       1 while True:
# ----> 2   T2 = threshold_update(gImg1.shape[0], gImg1.shape[1], gImg1, outImg, T1)
#       3
#       4   if(np.abs(T2-T1) < T0):
#       5       for w in range(gImg1.shape[1]):
#
# <ipython-input-45-9c2a017cf330> in threshold_update(h, w, img, output, T1)
#      15
#      16   avg1 = sum1 / count1
# ---> 17   avg2 = sum2 / count2
#      18
#      19   T2 = np.int32(avg1 + avg2)/2
#
# ZeroDivisionError: division by zero
